# %% [markdown]
# # Artificial Intelligence Nanodegree
#
# ## Convolutional Neural Networks
#
# ---
#
# In this notebook, we train a CNN on augmented images from the CIFAR-10 database.
#
# ### 1. Load CIFAR-10 Database

# %%
import keras
from keras.datasets import cifar10

# load the pre-shuffled train and test data
(x_train, y_train), (x_test, y_test) = cifar10.load_data()
# Out:
# Using TensorFlow backend.

# %% [markdown]
# ### 2. Visualize the First 24 Training Images

# %%
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline

fig = plt.figure(figsize=(20,5))
for i in range(36):
    ax = fig.add_subplot(3, 12, i + 1, xticks=[], yticks=[])
    ax.imshow(np.squeeze(x_train[i]))

# %% [markdown]
# ### 3. Rescale the Images by Dividing Every Pixel in Every Image by 255

# %%
# rescale [0,255] --> [0,1]
x_train = x_train.astype('float32')/255
x_test = x_test.astype('float32')/255

# %% [markdown]
# ### 4.  Break Dataset into Training, Testing, and Validation Sets

# %%
from keras.utils import np_utils

# break training set into training and validation sets
(x_train, x_valid) = x_train[5000:], x_train[:5000]
(y_train, y_valid) = y_train[5000:], y_train[:5000]

# one-hot encode the labels
num_classes = len(np.unique(y_train))
y_train = keras.utils.to_categorical(y_train, num_classes)
y_test = keras.utils.to_categorical(y_test, num_classes)
y_valid = keras.utils.to_categorical(y_valid, num_classes)

# print shape of training set
print('x_train shape:', x_train.shape)

# print number of training, validation, and test images
print(x_train.shape[0], 'train samples')
print(x_test.shape[0], 'test samples')
print(x_valid.shape[0], 'validation samples')
# Out:
# x_train shape: (45000, 32, 32, 3)
# 45000 train samples
# 10000 test samples
# 5000 validation samples

# %% [markdown]
# ### 5. Create and Configure Augmented Image Generator

# %%
from keras.preprocessing.image import ImageDataGenerator

# create and configure augmented image generator
# Also see https://keras.io/preprocessing/image/
datagen = ImageDataGenerator( #Generate batches of tensor image data with real-time data augmentation
    width_shift_range=0.1,  # randomly shift images horizontally (10% of total width)
    height_shift_range=0.1,  # randomly shift images vertically (10% of total height)
    horizontal_flip=True) # randomly flip images horizontally

# fit augmented image generator on data
datagen.fit(x_train)

# %% [markdown]
# ### 6. Visualize Original and Augmented Images

# %%
import matplotlib.pyplot as plt

# take subset of training data
x_train_subset = x_train[:12]

# visualize subset of training data
fig = plt.figure(figsize=(20,2))
for i in range(0, len(x_train_subset)):
    ax = fig.add_subplot(1, 12, i+1)
    ax.imshow(x_train_subset[i])
fig.suptitle('Subset of Original Training Images', fontsize=20)
plt.show()

# visualize augmented images
fig = plt.figure(figsize=(20,2))
for x_batch in datagen.flow(x_train_subset, batch_size=12):
    for i in range(0, 12):
        ax = fig.add_subplot(1, 12, i+1)
        ax.imshow(x_batch[i])
    fig.suptitle('Augmented Images', fontsize=20)
    plt.show()
    break;

# %% [markdown]
# ### 7. Define the Model Architecture

# %%
from keras.models import Sequential
from keras.layers import Conv2D, MaxPooling2D, Flatten, Dense, Dropout

model = Sequential()
model.add(Conv2D(filters=16, kernel_size=2, padding='same', activation='relu', 
                        input_shape=(32, 32, 3)))
model.add(MaxPooling2D(pool_size=2))
model.add(Conv2D(filters=32, kernel_size=2, padding='same', activation='relu'))
model.add(MaxPooling2D(pool_size=2))
model.add(Conv2D(filters=64, kernel_size=2, padding='same', activation='relu'))
model.add(MaxPooling2D(pool_size=2))
model.add(Dropout(0.3))
model.add(Flatten())
model.add(Dense(500, activation='relu'))
model.add(Dropout(0.4))
model.add(Dense(10, activation='softmax'))

model.summary()
# Out:
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d_1 (Conv2D)            (None, 32, 32, 16)        208
# _________________________________________________________________
# max_pooling2d_1 (MaxPooling2 (None, 16, 16, 16)        0
# _________________________________________________________________
# conv2d_2 (Conv2D)            (None, 16, 16, 32)        2080
# _________________________________________________________________
# max_pooling2d_2 (MaxPooling2 (None, 8, 8, 32)          0
# _________________________________________________________________
# conv2d_3 (Conv2D)            (None, 8, 8, 64)          8256
# _________________________________________________________________
# max_pooling2d_3 (MaxPooling2 (None, 4, 4, 64)          0
# _________________________________________________________________
# dropout_1 (Dropout)          (None, 4, 4, 64)          0
# _________________________________________________________________
# flatten_1 (Flatten)          (None, 1024)              0
# _________________________________________________________________
# dense_1 (Dense)              (None, 500)               512500
# _________________________________________________________________
# dropout_2 (Dropout)          (None, 500)               0
# _________________________________________________________________
# dense_2 (Dense)              (None, 10)                5010
# =================================================================
# Total params: 528,054
# Trainable params: 528,054
# Non-trainable params: 0
# _________________________________________________________________

# %% [markdown]
# ### 8. Compile the Model

# %%
# compile the model
model.compile(loss='categorical_crossentropy', optimizer='rmsprop', 
                  metrics=['accuracy'])

# %% [markdown]
# ### 9. Train the Model

# %%
from keras.callbacks import ModelCheckpoint   

batch_size = 32
epochs = 100

# train the model
checkpointer = ModelCheckpoint(filepath='aug_model.weights.best.hdf5', verbose=1, 
                               save_best_only=True)
model.fit_generator(datagen.flow(x_train, y_train, batch_size=batch_size),
                        steps_per_epoch=x_train.shape[0] // batch_size,
                        epochs=epochs, verbose=2, callbacks=[checkpointer],
                        validation_data=(x_valid, y_valid))
# Out:
# Epoch 1/100
# Epoch 00000: val_loss improved from inf to 1.37258, saving model to aug_model.weights.best.hdf5
# 22s - loss: 1.6587 - acc: 0.3981 - val_loss: 1.3726 - val_acc: 0.5098
# Epoch 2/100
# Epoch 00001: val_loss improved from 1.37258 to 1.14484, saving model to aug_model.weights.best.hdf5
# 19s - loss: 1.3662 - acc: 0.5110 - val_loss: 1.1448 - val_acc: 0.5866
# Epoch 3/100
# Epoch 00002: val_loss improved from 1.14484 to 1.04554, saving model to aug_model.weights.best.hdf5
# 18s - loss: 1.2541 - acc: 0.5535 - val_loss: 1.0455 - val_acc: 0.6378
# Epoch 4/100
# Epoch 00003: val_loss improved from 1.04554 to 1.01615, saving model to aug_model.weights.best.hdf5
# 19s - loss: 1.2023 - acc: 0.5737 - val_loss: 1.0162 - val_acc: 0.6460
# Epoch 5/100
# Epoch 00004: val_loss did not improve
# 18s - loss: 1.1739 - acc: 0.5870 - val_loss: 1.0415 - val_acc: 0.6440
# Epoch 6/100
# Epoch 00005: val_loss improved from 1.01615 to 0.96277, saving model to aug_model.weights.best.hdf5
# 19s - loss: 1.1510 - acc: 0.5967 - val_loss: 0.9628 - val_acc: 0.6718
# Epoch 7/100
# Epoch 00006: val_loss improved from 0.96277 to 0.95267, saving model to aug_model.weights.best.hdf5
# 18s - loss: 1.1448 - acc: 0.6029 - val_loss: 0.9527 - val_acc: 0.6816
# Epoch 8/100
# Epoch 00007: val_loss did not improve
# 19s - loss: 1.1615 - acc: 0.6011 - val_loss: 1.0071 - val_acc: 0.6648
# Epoch 9/100
# Epoch 00008: val_loss did not improve
# 19s - loss: 1.1650 - acc: 0.6016 - val_loss: 1.0209 - val_acc: 0.6580
# Epoch 10/100
# Epoch 00009: val_loss improved from 0.95267 to 0.93602, saving model to aug_model.weights.best.hdf5
# 19s - loss: 1.1700 - acc: 0.6037 - val_loss: 0.9360 - val_acc: 0.6860
# Epoch 11/100
# Epoch 00010: val_loss did not improve
# 19s - loss: 1.1915 - acc: 0.5963 - val_loss: 1.0783 - val_acc: 0.6504
# Epoch 12/100
# Epoch 00011: val_loss did not improve
# 19s - loss: 1.2126 - acc: 0.5881 - val_loss: 0.9905 - val_acc: 0.6576
# Epoch 13/100
# Epoch 00012: val_loss did not improve
# 18s - loss: 1.2266 - acc: 0.5842 - val_loss: 1.0816 - val_acc: 0.6172
# Epoch 14/100
# Epoch 00013: val_loss did not improve
# 18s - loss: 1.2520 - acc: 0.5764 - val_loss: 1.1671 - val_acc: 0.6268
# Epoch 15/100
# Epoch 00014: val_loss did not improve
# 19s - loss: 1.2531 - acc: 0.5753 - val_loss: 1.0182 - val_acc: 0.6558
# Epoch 16/100
# Epoch 00015: val_loss did not improve
# 19s - loss: 1.2718 - acc: 0.5711 - val_loss: 1.0158 - val_acc: 0.6734
# Epoch 17/100
# Epoch 00016: val_loss did not improve
# 19s - loss: 1.2762 - acc: 0.5705 - val_loss: 1.0520 - val_acc: 0.6442
# Epoch 18/100
# Epoch 00017: val_loss did not improve
# 18s - loss: 1.3005 - acc: 0.5622 - val_loss: 1.1789 - val_acc: 0.6020
# Epoch 19/100
# Epoch 00018: val_loss did not improve
# 18s - loss: 1.3145 - acc: 0.5582 - val_loss: 1.2602 - val_acc: 0.5804
# Epoch 20/100
# Epoch 00019: val_loss did not improve
# 19s - loss: 1.3310 - acc: 0.5497 - val_loss: 1.2969 - val_acc: 0.5712
# Epoch 21/100
# Epoch 00020: val_loss did not improve
# 19s - loss: 1.3650 - acc: 0.5440 - val_loss: 1.1924 - val_acc: 0.5806
# Epoch 22/100
# Epoch 00021: val_loss did not improve
# 19s - loss: 1.3833 - acc: 0.5371 - val_loss: 1.1995 - val_acc: 0.5762
# Epoch 23/100
# Epoch 00022: val_loss did not improve
# 19s - loss: 1.4010 - acc: 0.5296 - val_loss: 1.2822 - val_acc: 0.5576
# Epoch 24/100
# Epoch 00023: val_loss did not improve
# 19s - loss: 1.4186 - acc: 0.5240 - val_loss: 1.1577 - val_acc: 0.6006
# Epoch 25/100
# Epoch 00024: val_loss did not improve
# 19s - loss: 1.4467 - acc: 0.5107 - val_loss: 1.1567 - val_acc: 0.6084
# Epoch 26/100
# Epoch 00025: val_loss did not improve
# 19s - loss: 1.4722 - acc: 0.5050 - val_loss: 1.2144 - val_acc: 0.5834
# Epoch 27/100
# Epoch 00026: val_loss did not improve
# 18s - loss: 1.4890 - acc: 0.4945 - val_loss: 1.1810 - val_acc: 0.6006
# Epoch 28/100
# Epoch 00027: val_loss did not improve
# 19s - loss: 1.4995 - acc: 0.4917 - val_loss: 1.2220 - val_acc: 0.5904
# Epoch 29/100
# Epoch 00028: val_loss did not improve
# 19s - loss: 1.5253 - acc: 0.4871 - val_loss: 1.1872 - val_acc: 0.5934
# Epoch 30/100
# Epoch 00029: val_loss did not improve
# 19s - loss: 1.5480 - acc: 0.4730 - val_loss: 1.4234 - val_acc: 0.4934
# Epoch 31/100
# Epoch 00030: val_loss did not improve
# 19s - loss: 1.5742 - acc: 0.4663 - val_loss: 1.3581 - val_acc: 0.5348
# Epoch 32/100
# Epoch 00031: val_loss did not improve
# 19s - loss: 1.5885 - acc: 0.4650 - val_loss: 1.3071 - val_acc: 0.5466
# Epoch 33/100
# Epoch 00032: val_loss did not improve
# 18s - loss: 1.6032 - acc: 0.4544 - val_loss: 1.4161 - val_acc: 0.5000
# Epoch 34/100
# Epoch 00033: val_loss did not improve
# 19s - loss: 1.6204 - acc: 0.4528 - val_loss: 1.3558 - val_acc: 0.5524
# Epoch 35/100
# Epoch 00034: val_loss did not improve
# 19s - loss: 1.6233 - acc: 0.4439 - val_loss: 1.3539 - val_acc: 0.5338
# Epoch 36/100
# Epoch 00035: val_loss did not improve
# 19s - loss: 1.6289 - acc: 0.4468 - val_loss: 1.2533 - val_acc: 0.5718
# Epoch 37/100
# Epoch 00036: val_loss did not improve
# 18s - loss: 1.6475 - acc: 0.4395 - val_loss: 1.4339 - val_acc: 0.4916
# Epoch 38/100
# Epoch 00037: val_loss did not improve
# 18s - loss: 1.6438 - acc: 0.4375 - val_loss: 1.2739 - val_acc: 0.5564
# Epoch 39/100
# Epoch 00038: val_loss did not improve
# 18s - loss: 1.6684 - acc: 0.4300 - val_loss: 1.4922 - val_acc: 0.4852
# Epoch 40/100
# Epoch 00039: val_loss did not improve
# 19s - loss: 1.6758 - acc: 0.4275 - val_loss: 1.3936 - val_acc: 0.5222
# Epoch 41/100
# Epoch 00040: val_loss did not improve
# 18s - loss: 1.6873 - acc: 0.4197 - val_loss: 1.7175 - val_acc: 0.4852
# Epoch 42/100
# Epoch 00041: val_loss did not improve
# 18s - loss: 1.6906 - acc: 0.4235 - val_loss: 1.4021 - val_acc: 0.5068
# Epoch 43/100
# Epoch 00042: val_loss did not improve
# 19s - loss: 1.7160 - acc: 0.4131 - val_loss: 1.5067 - val_acc: 0.5024
# Epoch 44/100
# Epoch 00043: val_loss did not improve
# 18s - loss: 1.7400 - acc: 0.3998 - val_loss: 1.5426 - val_acc: 0.4622
# Epoch 45/100
# Epoch 00044: val_loss did not improve
# 18s - loss: 1.7201 - acc: 0.4054 - val_loss: 1.6442 - val_acc: 0.3898
# Epoch 46/100
# Epoch 00045: val_loss did not improve
# 18s - loss: 1.7469 - acc: 0.4027 - val_loss: 1.5719 - val_acc: 0.4416
# Epoch 47/100
# Epoch 00046: val_loss did not improve
# 19s - loss: 1.7544 - acc: 0.4011 - val_loss: 1.4467 - val_acc: 0.4666
# Epoch 48/100
# Epoch 00047: val_loss did not improve
# 19s - loss: 1.7456 - acc: 0.4034 - val_loss: 1.4232 - val_acc: 0.4978
# Epoch 49/100
# Epoch 00048: val_loss did not improve
# 18s - loss: 1.7353 - acc: 0.4001 - val_loss: 1.5770 - val_acc: 0.4590
# Epoch 50/100
# Epoch 00049: val_loss did not improve
# 18s - loss: 1.7552 - acc: 0.3956 - val_loss: 1.3636 - val_acc: 0.5208
# Epoch 51/100
# Epoch 00050: val_loss did not improve
# 18s - loss: 1.7424 - acc: 0.3994 - val_loss: 1.3805 - val_acc: 0.5150
# Epoch 52/100
# Epoch 00051: val_loss did not improve
# 18s - loss: 1.7680 - acc: 0.3902 - val_loss: 1.4475 - val_acc: 0.4772
# Epoch 53/100
# Epoch 00052: val_loss did not improve
# 18s - loss: 1.7468 - acc: 0.3970 - val_loss: 1.5168 - val_acc: 0.4832
# Epoch 54/100
# Epoch 00053: val_loss did not improve
# 18s - loss: 1.7571 - acc: 0.3884 - val_loss: 1.6254 - val_acc: 0.3862
# Epoch 55/100
# Epoch 00054: val_loss did not improve
# 18s - loss: 1.7636 - acc: 0.3870 - val_loss: 1.7110 - val_acc: 0.3698
# Epoch 56/100
# Epoch 00055: val_loss did not improve
# 18s - loss: 1.7675 - acc: 0.3843 - val_loss: 1.5651 - val_acc: 0.4140
# Epoch 57/100
# Epoch 00056: val_loss did not improve
# 18s - loss: 1.7737 - acc: 0.3812 - val_loss: 1.5704 - val_acc: 0.4058
# Epoch 58/100
# Epoch 00057: val_loss did not improve
# 18s - loss: 1.7662 - acc: 0.3837 - val_loss: 1.4651 - val_acc: 0.4630
# Epoch 59/100
# Epoch 00058: val_loss did not improve
# 18s - loss: 1.7801 - acc: 0.3757 - val_loss: 1.5247 - val_acc: 0.4612
# Epoch 60/100
# Epoch 00059: val_loss did not improve
# 18s - loss: 1.7701 - acc: 0.3793 - val_loss: 1.5428 - val_acc: 0.4654
# Epoch 61/100
# Epoch 00060: val_loss did not improve
# 18s - loss: 1.7579 - acc: 0.3823 - val_loss: 1.4262 - val_acc: 0.4948
# Epoch 62/100
# Epoch 00061: val_loss did not improve
# 18s - loss: 1.7698 - acc: 0.3837 - val_loss: 1.4231 - val_acc: 0.5004
# Epoch 63/100
# Epoch 00062: val_loss did not improve
# 18s - loss: 1.7709 - acc: 0.3788 - val_loss: 1.4977 - val_acc: 0.4506
# Epoch 64/100
# Epoch 00063: val_loss did not improve
# 19s - loss: 1.7759 - acc: 0.3772 - val_loss: 1.6383 - val_acc: 0.4392
# Epoch 65/100
# Epoch 00064: val_loss did not improve
# 18s - loss: 1.7552 - acc: 0.3770 - val_loss: 1.5267 - val_acc: 0.4580
# Epoch 66/100
# Epoch 00065: val_loss did not improve
# 18s - loss: 1.7699 - acc: 0.3783 - val_loss: 1.5982 - val_acc: 0.3956
# Epoch 67/100
# Epoch 00066: val_loss did not improve
# 18s - loss: 1.7840 - acc: 0.3722 - val_loss: 1.6219 - val_acc: 0.4114
# Epoch 68/100
# Epoch 00067: val_loss did not improve
# 18s - loss: 1.7605 - acc: 0.3749 - val_loss: 1.7490 - val_acc: 0.3662
# Epoch 69/100
# Epoch 00068: val_loss did not improve
# 18s - loss: 1.7675 - acc: 0.3736 - val_loss: 1.5450 - val_acc: 0.4372
# Epoch 70/100
# Epoch 00069: val_loss did not improve
# 19s - loss: 1.7704 - acc: 0.3734 - val_loss: 1.5193 - val_acc: 0.4774
# Epoch 71/100
# Epoch 00070: val_loss did not improve
# 19s - loss: 1.7890 - acc: 0.3701 - val_loss: 1.5091 - val_acc: 0.4538
# Epoch 72/100
# Epoch 00071: val_loss did not improve
# 18s - loss: 1.7905 - acc: 0.3646 - val_loss: 1.7562 - val_acc: 0.3942
# Epoch 73/100
# Epoch 00072: val_loss did not improve
# 18s - loss: 1.7847 - acc: 0.3676 - val_loss: 1.4910 - val_acc: 0.4724
# Epoch 74/100
# Epoch 00073: val_loss did not improve
# 18s - loss: 1.7890 - acc: 0.3673 - val_loss: 1.4682 - val_acc: 0.4454
# Epoch 75/100
# Epoch 00074: val_loss did not improve
# 18s - loss: 1.7894 - acc: 0.3671 - val_loss: 1.5314 - val_acc: 0.4474
# Epoch 76/100
# Epoch 00075: val_loss did not improve
# 18s - loss: 1.7993 - acc: 0.3610 - val_loss: 1.6466 - val_acc: 0.4244
# Epoch 77/100
# Epoch 00076: val_loss did not improve
# 18s - loss: 1.8004 - acc: 0.3585 - val_loss: 1.4768 - val_acc: 0.4860
# Epoch 78/100
# Epoch 00077: val_loss did not improve
# 18s - loss: 1.8101 - acc: 0.3588 - val_loss: 1.5993 - val_acc: 0.4320
# Epoch 79/100
# Epoch 00078: val_loss did not improve
# 18s - loss: 1.8013 - acc: 0.3583 - val_loss: 1.7073 - val_acc: 0.4008
# Epoch 80/100
# Epoch 00079: val_loss did not improve
# 18s - loss: 1.8153 - acc: 0.3553 - val_loss: 1.5642 - val_acc: 0.4084
# Epoch 81/100
# Epoch 00080: val_loss did not improve
# 18s - loss: 1.8065 - acc: 0.3584 - val_loss: 1.7539 - val_acc: 0.3594
# Epoch 82/100
# Epoch 00081: val_loss did not improve
# 19s - loss: 1.8028 - acc: 0.3607 - val_loss: 1.5143 - val_acc: 0.4652
# Epoch 83/100
# Epoch 00082: val_loss did not improve
# 18s - loss: 1.7940 - acc: 0.3606 - val_loss: 1.5161 - val_acc: 0.4658
# Epoch 84/100
# Epoch 00083: val_loss did not improve
# 18s - loss: 1.8155 - acc: 0.3551 - val_loss: 1.5413 - val_acc: 0.4486
# Epoch 85/100
# Epoch 00084: val_loss did not improve
# 18s - loss: 1.8154 - acc: 0.3529 - val_loss: 1.5957 - val_acc: 0.4106
# Epoch 86/100
# Epoch 00085: val_loss did not improve
# 18s - loss: 1.8229 - acc: 0.3468 - val_loss: 1.7003 - val_acc: 0.4252
# Epoch 87/100
# Epoch 00086: val_loss did not improve
# 18s - loss: 1.8297 - acc: 0.3465 - val_loss: 1.8137 - val_acc: 0.3606
# Epoch 88/100
# Epoch 00087: val_loss did not improve
# 18s - loss: 1.8105 - acc: 0.3532 - val_loss: 1.6172 - val_acc: 0.4390
# Epoch 89/100
# Epoch 00088: val_loss did not improve
# 19s - loss: 1.8251 - acc: 0.3520 - val_loss: 1.6910 - val_acc: 0.3636
# Epoch 90/100
# Epoch 00089: val_loss did not improve
# 18s - loss: 1.8293 - acc: 0.3515 - val_loss: 1.5250 - val_acc: 0.4458
# Epoch 91/100
# Epoch 00090: val_loss did not improve
# 18s - loss: 1.8332 - acc: 0.3480 - val_loss: 1.6512 - val_acc: 0.4136
# Epoch 92/100
# Epoch 00091: val_loss did not improve
# 19s - loss: 1.8398 - acc: 0.3484 - val_loss: 1.7734 - val_acc: 0.3848
# Epoch 93/100
# Epoch 00092: val_loss did not improve
# 18s - loss: 1.8319 - acc: 0.3484 - val_loss: 1.5723 - val_acc: 0.4436
# Epoch 94/100
# Epoch 00093: val_loss did not improve
# 18s - loss: 1.8335 - acc: 0.3451 - val_loss: 1.5904 - val_acc: 0.4268
# Epoch 95/100
# Epoch 00094: val_loss did not improve
# 18s - loss: 1.8457 - acc: 0.3435 - val_loss: 1.6365 - val_acc: 0.3926
# Epoch 96/100
# Epoch 00095: val_loss did not improve
# 18s - loss: 1.8363 - acc: 0.3484 - val_loss: 1.5134 - val_acc: 0.4614
# Epoch 97/100
# Epoch 00096: val_loss did not improve
# 18s - loss: 1.8414 - acc: 0.3422 - val_loss: 1.6511 - val_acc: 0.3842
# Epoch 98/100
# Epoch 00097: val_loss did not improve
# 18s - loss: 1.8451 - acc: 0.3416 - val_loss: 1.5396 - val_acc: 0.4484
# Epoch 99/100
# Epoch 00098: val_loss did not improve
# 18s - loss: 1.8446 - acc: 0.3384 - val_loss: 1.6510 - val_acc: 0.3922
# Epoch 100/100
# Epoch 00099: val_loss did not improve
# 19s - loss: 1.8399 - acc: 0.3365 - val_loss: 1.5548 - val_acc: 0.4162

# %% [markdown]
# ### 10. Load the Model with the Best Validation Accuracy

# %%
# load the weights that yielded the best validation accuracy
model.load_weights('aug_model.weights.best.hdf5')

# %% [markdown]
# ### 11. Calculate Classification Accuracy on Test Set

# %%
# evaluate and print test accuracy
score = model.evaluate(x_test, y_test, verbose=0)
print('\n', 'Test accuracy:', score[1])
# Out:
#  Test accuracy: 0.6764
