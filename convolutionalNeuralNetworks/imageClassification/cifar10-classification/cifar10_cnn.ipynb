# %% [markdown]
# # Artificial Intelligence Nanodegree
#
# ## Convolutional Neural Networks
#
# ---
#
# In this notebook, we train a CNN to classify images from the CIFAR-10 database.
#
# ### 1. Load CIFAR-10 Database

# %%
import keras
from keras.datasets import cifar10

# load the pre-shuffled train and test data
(x_train, y_train), (x_test, y_test) = cifar10.load_data()
# Out:
# Using TensorFlow backend.

# %% [markdown]
# ### 2. Visualize the First 24 Training Images

# %%
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline

fig = plt.figure(figsize=(20,5))
for i in range(36):
    ax = fig.add_subplot(3, 12, i + 1, xticks=[], yticks=[])
    ax.imshow(np.squeeze(x_train[i]))

# %% [markdown]
# ### 3. Rescale the Images by Dividing Every Pixel in Every Image by 255

# %%
# rescale [0,255] --> [0,1]
x_train = x_train.astype('float32')/255
x_test = x_test.astype('float32')/255

# %% [markdown]
# ### 4.  Break Dataset into Training, Testing, and Validation Sets

# %%
from keras.utils import np_utils

# one-hot encode the labels
num_classes = len(np.unique(y_train))
y_train = keras.utils.to_categorical(y_train, num_classes)
y_test = keras.utils.to_categorical(y_test, num_classes)

# break training set into training and validation sets
(x_train, x_valid) = x_train[5000:], x_train[:5000]
(y_train, y_valid) = y_train[5000:], y_train[:5000]

# print shape of training set
print('x_train shape:', x_train.shape)

# print number of training, validation, and test images
print(x_train.shape[0], 'train samples')
print(x_test.shape[0], 'test samples')
print(x_valid.shape[0], 'validation samples')
# Out:
# x_train shape: (45000, 32, 32, 3)
# 45000 train samples
# 10000 test samples
# 5000 validation samples

# %% [markdown]
# ### 5. Define the Model Architecture

# %%
# Examples : https://github.com/fchollet/keras/blob/master/examples/cifar10_cnn.py
from keras.models import Sequential
from keras.layers import Conv2D, MaxPooling2D, Flatten, Dense, Dropout

model = Sequential()
model.add(Conv2D(filters=16, kernel_size=2, padding='same', activation='relu', 
                        input_shape=(32, 32, 3)))
model.add(MaxPooling2D(pool_size=2))
model.add(Dropout(0.25))
model.add(Conv2D(filters=32, kernel_size=2, padding='same', activation='relu'))
model.add(MaxPooling2D(pool_size=2))
model.add(Dropout(0.25))
model.add(Conv2D(filters=64, kernel_size=2, padding='same', activation='relu'))
model.add(MaxPooling2D(pool_size=2))
model.add(Dropout(0.3))
model.add(Flatten())
model.add(Dense(500, activation='relu'))
model.add(Dropout(0.4))
model.add(Dense(10, activation='softmax'))

model.summary()
# Out:
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d_1 (Conv2D)            (None, 32, 32, 16)        208
# _________________________________________________________________
# max_pooling2d_1 (MaxPooling2 (None, 16, 16, 16)        0
# _________________________________________________________________
# dropout_1 (Dropout)          (None, 16, 16, 16)        0
# _________________________________________________________________
# conv2d_2 (Conv2D)            (None, 16, 16, 32)        2080
# _________________________________________________________________
# max_pooling2d_2 (MaxPooling2 (None, 8, 8, 32)          0
# _________________________________________________________________
# dropout_2 (Dropout)          (None, 8, 8, 32)          0
# _________________________________________________________________
# conv2d_3 (Conv2D)            (None, 8, 8, 64)          8256
# _________________________________________________________________
# max_pooling2d_3 (MaxPooling2 (None, 4, 4, 64)          0
# _________________________________________________________________
# dropout_3 (Dropout)          (None, 4, 4, 64)          0
# _________________________________________________________________
# flatten_1 (Flatten)          (None, 1024)              0
# _________________________________________________________________
# dense_1 (Dense)              (None, 500)               512500
# _________________________________________________________________
# dropout_4 (Dropout)          (None, 500)               0
# _________________________________________________________________
# dense_2 (Dense)              (None, 10)                5010
# =================================================================
# Total params: 528,054
# Trainable params: 528,054
# Non-trainable params: 0
# _________________________________________________________________

# %% [markdown]
# ### 6. Compile the Model

# %%
# compile the model
model.compile(loss='categorical_crossentropy', optimizer='rmsprop', 
                  metrics=['accuracy'])

# %% [markdown]
# ### 7. Train the Model

# %%
from keras.callbacks import ModelCheckpoint   

# train the model
checkpointer = ModelCheckpoint(filepath='model.weights.best.hdf5', verbose=1, 
                               save_best_only=True)
hist = model.fit(x_train, y_train, batch_size=32, epochs=100,
          validation_data=(x_valid, y_valid), callbacks=[checkpointer], 
          verbose=2, shuffle=True)
# Out:
# Train on 45000 samples, validate on 5000 samples
# Epoch 1/100
# Epoch 00000: val_loss improved from inf to 1.46141, saving model to model.weights.best.hdf5
# 15s - loss: 1.7101 - acc: 0.3762 - val_loss: 1.4614 - val_acc: 0.4706
# Epoch 2/100
# Epoch 00001: val_loss improved from 1.46141 to 1.32564, saving model to model.weights.best.hdf5
# 14s - loss: 1.4152 - acc: 0.4916 - val_loss: 1.3256 - val_acc: 0.5088
# Epoch 3/100
# Epoch 00002: val_loss improved from 1.32564 to 1.19688, saving model to model.weights.best.hdf5
# 14s - loss: 1.3158 - acc: 0.5317 - val_loss: 1.1969 - val_acc: 0.5800
# Epoch 4/100
# Epoch 00003: val_loss did not improve
# 14s - loss: 1.2569 - acc: 0.5510 - val_loss: 1.5212 - val_acc: 0.4962
# Epoch 5/100
# Epoch 00004: val_loss did not improve
# 14s - loss: 1.2204 - acc: 0.5689 - val_loss: 1.4735 - val_acc: 0.5102
# Epoch 6/100
# Epoch 00005: val_loss did not improve
# 14s - loss: 1.2040 - acc: 0.5772 - val_loss: 2.1742 - val_acc: 0.3604
# Epoch 7/100
# Epoch 00006: val_loss improved from 1.19688 to 1.16300, saving model to model.weights.best.hdf5
# 14s - loss: 1.1942 - acc: 0.5812 - val_loss: 1.1630 - val_acc: 0.5974
# Epoch 8/100
# Epoch 00007: val_loss did not improve
# 14s - loss: 1.1932 - acc: 0.5845 - val_loss: 1.5557 - val_acc: 0.4828
# Epoch 9/100
# Epoch 00008: val_loss did not improve
# 14s - loss: 1.1849 - acc: 0.5874 - val_loss: 1.3830 - val_acc: 0.5410
# Epoch 10/100
# Epoch 00009: val_loss did not improve
# 14s - loss: 1.1844 - acc: 0.5915 - val_loss: 1.3591 - val_acc: 0.5466
# Epoch 11/100
# Epoch 00010: val_loss improved from 1.16300 to 1.14238, saving model to model.weights.best.hdf5
# 14s - loss: 1.1880 - acc: 0.5904 - val_loss: 1.1424 - val_acc: 0.6420
# Epoch 12/100
# Epoch 00011: val_loss did not improve
# 14s - loss: 1.1884 - acc: 0.5911 - val_loss: 1.1734 - val_acc: 0.6212
# Epoch 13/100
# Epoch 00012: val_loss did not improve
# 14s - loss: 1.2002 - acc: 0.5867 - val_loss: 1.5305 - val_acc: 0.5408
# Epoch 14/100
# Epoch 00013: val_loss did not improve
# 14s - loss: 1.1981 - acc: 0.5902 - val_loss: 1.4111 - val_acc: 0.5486
# Epoch 15/100
# Epoch 00014: val_loss did not improve
# 14s - loss: 1.2072 - acc: 0.5874 - val_loss: 1.4499 - val_acc: 0.5404
# Epoch 16/100
# Epoch 00015: val_loss did not improve
# 14s - loss: 1.2128 - acc: 0.5836 - val_loss: 1.2324 - val_acc: 0.6180
# Epoch 17/100
# Epoch 00016: val_loss did not improve
# 14s - loss: 1.2063 - acc: 0.5886 - val_loss: 1.1701 - val_acc: 0.6338
# Epoch 18/100
# Epoch 00017: val_loss improved from 1.14238 to 1.12562, saving model to model.weights.best.hdf5
# 14s - loss: 1.2155 - acc: 0.5863 - val_loss: 1.1256 - val_acc: 0.6362
# Epoch 19/100
# Epoch 00018: val_loss did not improve
# 14s - loss: 1.2249 - acc: 0.5829 - val_loss: 1.3855 - val_acc: 0.5488
# Epoch 20/100
# Epoch 00019: val_loss did not improve
# 14s - loss: 1.2309 - acc: 0.5810 - val_loss: 1.1353 - val_acc: 0.6120
# Epoch 21/100
# Epoch 00020: val_loss did not improve
# 14s - loss: 1.2309 - acc: 0.5812 - val_loss: 1.3575 - val_acc: 0.5564
# Epoch 22/100
# Epoch 00021: val_loss did not improve
# 14s - loss: 1.2431 - acc: 0.5751 - val_loss: 1.5352 - val_acc: 0.5034
# Epoch 23/100
# Epoch 00022: val_loss did not improve
# 14s - loss: 1.2422 - acc: 0.5773 - val_loss: 1.7070 - val_acc: 0.4786
# Epoch 24/100
# Epoch 00023: val_loss did not improve
# 14s - loss: 1.2473 - acc: 0.5773 - val_loss: 1.4168 - val_acc: 0.5284
# Epoch 25/100
# Epoch 00024: val_loss did not improve
# 14s - loss: 1.2484 - acc: 0.5721 - val_loss: 1.5188 - val_acc: 0.5284
# Epoch 26/100
# Epoch 00025: val_loss did not improve
# 14s - loss: 1.2591 - acc: 0.5695 - val_loss: 1.3192 - val_acc: 0.5594
# Epoch 27/100
# Epoch 00026: val_loss did not improve
# 14s - loss: 1.2588 - acc: 0.5752 - val_loss: 1.4113 - val_acc: 0.4996
# Epoch 28/100
# Epoch 00027: val_loss did not improve
# 14s - loss: 1.2694 - acc: 0.5694 - val_loss: 1.3279 - val_acc: 0.5850
# Epoch 29/100
# Epoch 00028: val_loss did not improve
# 14s - loss: 1.2766 - acc: 0.5660 - val_loss: 1.2268 - val_acc: 0.5796
# Epoch 30/100
# Epoch 00029: val_loss did not improve
# 14s - loss: 1.2751 - acc: 0.5648 - val_loss: 1.4722 - val_acc: 0.4956
# Epoch 31/100
# Epoch 00030: val_loss did not improve
# 14s - loss: 1.2856 - acc: 0.5638 - val_loss: 1.4142 - val_acc: 0.5244
# Epoch 32/100
# Epoch 00031: val_loss did not improve
# 14s - loss: 1.2919 - acc: 0.5618 - val_loss: 1.3063 - val_acc: 0.5826
# Epoch 33/100
# Epoch 00032: val_loss did not improve
# 14s - loss: 1.2928 - acc: 0.5607 - val_loss: 1.1707 - val_acc: 0.5928
# Epoch 34/100
# Epoch 00033: val_loss did not improve
# 14s - loss: 1.2944 - acc: 0.5564 - val_loss: 1.5672 - val_acc: 0.4656
# Epoch 35/100
# Epoch 00034: val_loss did not improve
# 14s - loss: 1.3019 - acc: 0.5547 - val_loss: 1.7038 - val_acc: 0.4068
# Epoch 36/100
# Epoch 00035: val_loss did not improve
# 14s - loss: 1.3015 - acc: 0.5578 - val_loss: 1.3500 - val_acc: 0.5408
# Epoch 37/100
# Epoch 00036: val_loss did not improve
# 14s - loss: 1.2999 - acc: 0.5525 - val_loss: 1.4651 - val_acc: 0.4996
# Epoch 38/100
# Epoch 00037: val_loss did not improve
# 14s - loss: 1.3069 - acc: 0.5559 - val_loss: 1.3982 - val_acc: 0.5080
# Epoch 39/100
# Epoch 00038: val_loss did not improve
# 14s - loss: 1.3162 - acc: 0.5496 - val_loss: 1.2283 - val_acc: 0.6114
# Epoch 40/100
# Epoch 00039: val_loss did not improve
# 14s - loss: 1.3184 - acc: 0.5510 - val_loss: 1.3169 - val_acc: 0.5680
# Epoch 41/100
# Epoch 00040: val_loss did not improve
# 14s - loss: 1.3224 - acc: 0.5483 - val_loss: 1.5183 - val_acc: 0.5080
# Epoch 42/100
# Epoch 00041: val_loss did not improve
# 14s - loss: 1.3207 - acc: 0.5507 - val_loss: 1.9847 - val_acc: 0.3226
# Epoch 43/100
# Epoch 00042: val_loss did not improve
# 14s - loss: 1.3308 - acc: 0.5464 - val_loss: 1.4126 - val_acc: 0.5342
# Epoch 44/100
# Epoch 00043: val_loss did not improve
# 14s - loss: 1.3333 - acc: 0.5457 - val_loss: 1.8531 - val_acc: 0.3202
# Epoch 45/100
# Epoch 00044: val_loss did not improve
# 14s - loss: 1.3422 - acc: 0.5409 - val_loss: 1.3510 - val_acc: 0.5622
# Epoch 46/100
# Epoch 00045: val_loss did not improve
# 14s - loss: 1.3330 - acc: 0.5422 - val_loss: 1.5309 - val_acc: 0.4682
# Epoch 47/100
# Epoch 00046: val_loss did not improve
# 14s - loss: 1.3374 - acc: 0.5411 - val_loss: 1.8970 - val_acc: 0.3540
# Epoch 48/100
# Epoch 00047: val_loss did not improve
# 14s - loss: 1.3529 - acc: 0.5380 - val_loss: 1.4147 - val_acc: 0.5622
# Epoch 49/100
# Epoch 00048: val_loss did not improve
# 14s - loss: 1.3539 - acc: 0.5379 - val_loss: 1.3032 - val_acc: 0.5384
# Epoch 50/100
# Epoch 00049: val_loss did not improve
# 14s - loss: 1.3591 - acc: 0.5318 - val_loss: 1.6878 - val_acc: 0.4586
# Epoch 51/100
# Epoch 00050: val_loss did not improve
# 14s - loss: 1.3554 - acc: 0.5378 - val_loss: 1.4614 - val_acc: 0.5088
# Epoch 52/100
# Epoch 00051: val_loss did not improve
# 14s - loss: 1.3587 - acc: 0.5340 - val_loss: 1.4945 - val_acc: 0.4990
# Epoch 53/100
# Epoch 00052: val_loss did not improve
# 14s - loss: 1.3682 - acc: 0.5332 - val_loss: 1.1887 - val_acc: 0.5946
# Epoch 54/100
# Epoch 00053: val_loss did not improve
# 14s - loss: 1.3688 - acc: 0.5323 - val_loss: 1.3234 - val_acc: 0.5354
# Epoch 55/100
# Epoch 00054: val_loss did not improve
# 14s - loss: 1.3730 - acc: 0.5326 - val_loss: 1.5070 - val_acc: 0.4926
# Epoch 56/100
# Epoch 00055: val_loss did not improve
# 14s - loss: 1.3674 - acc: 0.5334 - val_loss: 1.3654 - val_acc: 0.5576
# Epoch 57/100
# Epoch 00056: val_loss did not improve
# 14s - loss: 1.3706 - acc: 0.5270 - val_loss: 1.2474 - val_acc: 0.5576
# Epoch 58/100
# Epoch 00057: val_loss did not improve
# 14s - loss: 1.3794 - acc: 0.5291 - val_loss: 1.5753 - val_acc: 0.5038
# Epoch 59/100
# Epoch 00058: val_loss did not improve
# 14s - loss: 1.3915 - acc: 0.5244 - val_loss: 1.2715 - val_acc: 0.5738
# Epoch 60/100
# Epoch 00059: val_loss did not improve
# 14s - loss: 1.3885 - acc: 0.5259 - val_loss: 1.2932 - val_acc: 0.5638
# Epoch 61/100
# Epoch 00060: val_loss did not improve
# 14s - loss: 1.3907 - acc: 0.5262 - val_loss: 1.3429 - val_acc: 0.5470
# Epoch 62/100
# Epoch 00061: val_loss did not improve
# 14s - loss: 1.3958 - acc: 0.5226 - val_loss: 1.2803 - val_acc: 0.5744
# Epoch 63/100
# Epoch 00062: val_loss did not improve
# 14s - loss: 1.3979 - acc: 0.5188 - val_loss: 1.3434 - val_acc: 0.5438
# Epoch 64/100
# Epoch 00063: val_loss did not improve
# 14s - loss: 1.4117 - acc: 0.5127 - val_loss: 1.3384 - val_acc: 0.5698
# Epoch 65/100
# Epoch 00064: val_loss did not improve
# 14s - loss: 1.4150 - acc: 0.5183 - val_loss: 1.6271 - val_acc: 0.4414
# Epoch 66/100
# Epoch 00065: val_loss did not improve
# 14s - loss: 1.4161 - acc: 0.5161 - val_loss: 1.6696 - val_acc: 0.4206
# Epoch 67/100
# Epoch 00066: val_loss did not improve
# 14s - loss: 1.4148 - acc: 0.5158 - val_loss: 1.5322 - val_acc: 0.4562
# Epoch 68/100
# Epoch 00067: val_loss did not improve
# 14s - loss: 1.4089 - acc: 0.5158 - val_loss: 1.2760 - val_acc: 0.5494
# Epoch 69/100
# Epoch 00068: val_loss did not improve
# 14s - loss: 1.4129 - acc: 0.5141 - val_loss: 1.5661 - val_acc: 0.4240
# Epoch 70/100
# Epoch 00069: val_loss did not improve
# 14s - loss: 1.4266 - acc: 0.5089 - val_loss: 1.9360 - val_acc: 0.3262
# Epoch 71/100
# Epoch 00070: val_loss did not improve
# 14s - loss: 1.4182 - acc: 0.5134 - val_loss: 1.3881 - val_acc: 0.5036
# Epoch 72/100
# Epoch 00071: val_loss did not improve
# 14s - loss: 1.4191 - acc: 0.5110 - val_loss: 1.6589 - val_acc: 0.4044
# Epoch 73/100
# Epoch 00072: val_loss did not improve
# 14s - loss: 1.4320 - acc: 0.5072 - val_loss: 1.3883 - val_acc: 0.5482
# Epoch 74/100
# Epoch 00073: val_loss did not improve
# 14s - loss: 1.4208 - acc: 0.5113 - val_loss: 1.4843 - val_acc: 0.4594
# Epoch 75/100
# Epoch 00074: val_loss did not improve
# 14s - loss: 1.4287 - acc: 0.5079 - val_loss: 1.3792 - val_acc: 0.5108
# Epoch 76/100
# Epoch 00075: val_loss did not improve
# 14s - loss: 1.4390 - acc: 0.5066 - val_loss: 1.2034 - val_acc: 0.5750
# Epoch 77/100
# Epoch 00076: val_loss did not improve
# 14s - loss: 1.4343 - acc: 0.5080 - val_loss: 2.0671 - val_acc: 0.3102
# Epoch 78/100
# Epoch 00077: val_loss did not improve
# 14s - loss: 1.4382 - acc: 0.5039 - val_loss: 1.2661 - val_acc: 0.5566
# Epoch 79/100
# Epoch 00078: val_loss did not improve
# 14s - loss: 1.4354 - acc: 0.5066 - val_loss: 1.5934 - val_acc: 0.4558
# Epoch 80/100
# Epoch 00079: val_loss did not improve
# 14s - loss: 1.4377 - acc: 0.5070 - val_loss: 1.4111 - val_acc: 0.5152
# Epoch 81/100
# Epoch 00080: val_loss did not improve
# 14s - loss: 1.4518 - acc: 0.5004 - val_loss: 1.3109 - val_acc: 0.5660
# Epoch 82/100
# Epoch 00081: val_loss did not improve
# 14s - loss: 1.4507 - acc: 0.5008 - val_loss: 1.7217 - val_acc: 0.3776
# Epoch 83/100
# Epoch 00082: val_loss did not improve
# 14s - loss: 1.4522 - acc: 0.4989 - val_loss: 1.8540 - val_acc: 0.3474
# Epoch 84/100
# Epoch 00083: val_loss did not improve
# 14s - loss: 1.4509 - acc: 0.4974 - val_loss: 1.4412 - val_acc: 0.5030
# Epoch 85/100
# Epoch 00084: val_loss did not improve
# 14s - loss: 1.4594 - acc: 0.4982 - val_loss: 1.9339 - val_acc: 0.3432
# Epoch 86/100
# Epoch 00085: val_loss did not improve
# 14s - loss: 1.4625 - acc: 0.4997 - val_loss: 1.7423 - val_acc: 0.3672
# Epoch 87/100
# Epoch 00086: val_loss did not improve
# 14s - loss: 1.4578 - acc: 0.4971 - val_loss: 1.3030 - val_acc: 0.5466
# Epoch 88/100
# Epoch 00087: val_loss did not improve
# 14s - loss: 1.4621 - acc: 0.4983 - val_loss: 1.5212 - val_acc: 0.4758
# Epoch 89/100
# Epoch 00088: val_loss did not improve
# 14s - loss: 1.4629 - acc: 0.4940 - val_loss: 1.4970 - val_acc: 0.4394
# Epoch 90/100
# Epoch 00089: val_loss did not improve
# 14s - loss: 1.4651 - acc: 0.4944 - val_loss: 1.3019 - val_acc: 0.5296
# Epoch 91/100
# Epoch 00090: val_loss did not improve
# 14s - loss: 1.4710 - acc: 0.4938 - val_loss: 1.3075 - val_acc: 0.5512
# Epoch 92/100
# Epoch 00091: val_loss did not improve
# 14s - loss: 1.4555 - acc: 0.4995 - val_loss: 1.3977 - val_acc: 0.5078
# Epoch 93/100
# Epoch 00092: val_loss did not improve
# 14s - loss: 1.4651 - acc: 0.4922 - val_loss: 1.3453 - val_acc: 0.5092
# Epoch 94/100
# Epoch 00093: val_loss did not improve
# 14s - loss: 1.4855 - acc: 0.4897 - val_loss: 1.4176 - val_acc: 0.5432
# Epoch 95/100
# Epoch 00094: val_loss did not improve
# 14s - loss: 1.4628 - acc: 0.4917 - val_loss: 1.2529 - val_acc: 0.5684
# Epoch 96/100
# Epoch 00095: val_loss did not improve
# 14s - loss: 1.4714 - acc: 0.4904 - val_loss: 1.4413 - val_acc: 0.4966
# Epoch 97/100
# Epoch 00096: val_loss did not improve
# 14s - loss: 1.4793 - acc: 0.4893 - val_loss: 2.5940 - val_acc: 0.1654
# Epoch 98/100
# Epoch 00097: val_loss did not improve
# 14s - loss: 1.4820 - acc: 0.4868 - val_loss: 1.6623 - val_acc: 0.5074
# Epoch 99/100
# Epoch 00098: val_loss did not improve
# 14s - loss: 1.4802 - acc: 0.4906 - val_loss: 1.6616 - val_acc: 0.4542
# Epoch 100/100
# Epoch 00099: val_loss did not improve
# 14s - loss: 1.4821 - acc: 0.4869 - val_loss: 1.4922 - val_acc: 0.4672

# %% [markdown]
# ### 8. Load the Model with the Best Validation Accuracy

# %%
# load the weights that yielded the best validation accuracy
model.load_weights('model.weights.best.hdf5')

# %% [markdown]
# ### 9. Calculate Classification Accuracy on Test Set

# %%
# evaluate and print test accuracy
score = model.evaluate(x_test, y_test, verbose=0)
print('\n', 'Test accuracy:', score[1])
# Out:
#  Test accuracy: 0.626

# %% [markdown]
# ### 10. Visualize Some Predictions
#
# This may give you some insight into why the network is misclassifying certain objects.

# %%
# get predictions on the test set
y_hat = model.predict(x_test)

# define text labels (source: https://www.cs.toronto.edu/~kriz/cifar.html)
cifar10_labels = ['airplane', 'automobile', 'bird', 'cat', 'deer', 'dog', 'frog', 'horse', 'ship', 'truck']

# %%
# plot a random sample of test images, their predicted labels, and ground truth
fig = plt.figure(figsize=(20, 8))
for i, idx in enumerate(np.random.choice(x_test.shape[0], size=32, replace=False)):
    ax = fig.add_subplot(4, 8, i + 1, xticks=[], yticks=[])
    ax.imshow(np.squeeze(x_test[idx]))
    pred_idx = np.argmax(y_hat[idx])
    true_idx = np.argmax(y_test[idx])
    ax.set_title("{} ({})".format(cifar10_labels[pred_idx], cifar10_labels[true_idx]),
                 color=("green" if pred_idx == true_idx else "red"))
